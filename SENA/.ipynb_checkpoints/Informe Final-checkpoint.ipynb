# %% [markdown]
# >#### Se importan las librerias que se utilizaran durante el analisis de datos

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# >#### Se guardan los datos en la variable _df_

# %%
df = pd.read_csv('Inmuebles_Disponibles_Para_La_Venta.csv')

# %% [markdown]
# >#### Visualizamos la forma de los datos de analisis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 448 entries, 0 to 447
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Codigo                  448 non-null    int64
#  1   Ciudad                  448 non-null    object
#  2   Departamento            448 non-null    object
#  3   Barrio                  59 non-null     object
#  4   Direccion               448 non-null    object
#  5   Area Terreno            448 non-null    int64
#  6   Area Construida         448 non-null    int64
#  7   Detalle Disponibilidad  448 non-null    object
#  8   Estrato                 448 non-null    object
#  9   Precio                  448 non-null    int64
#  10  Tipo de Inmueble        448 non-null    object
#  11  Datos Adicionales       77 non-null     object
# dtypes: int64(4), object(8)
# memory usage: 42.1+ KB

# %% [markdown]
# >#### Lo primero para realizar el analisis es ordenar los datos.
#
# >#### Con el comando `df.isnull().sum()` podemos verificar si existen espacios vacios o valores nulos en alguna de las columnas de nuestros datos

# %%
df.isnull().sum()
# Out:
# Codigo                      0
# Ciudad                      0
# Departamento                0
# Barrio                    423
# Direccion                   0
# Area Terreno                0
# Area Construida             0
# Detalle Disponibilidad      0
# Estrato                     0
# Precio                      0
# Tipo de Inmueble            0
# Datos Adicionales         345
# dtype: int64

# %% [markdown]
# >#### Procedemos a eliminar las filas que contienen resgistros nulos

# %%
df = df.dropna()

# %% [markdown]
# >#### Verificamos que todas las columnas poseen el mismo numero de registros

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23 entries, 3 to 462
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Codigo                  23 non-null     int64
#  1   Ciudad                  23 non-null     object
#  2   Departamento            23 non-null     object
#  3   Barrio                  23 non-null     object
#  4   Direccion               23 non-null     object
#  5   Area Terreno            23 non-null     float64
#  6   Area Construida         23 non-null     float64
#  7   Detalle Disponibilidad  23 non-null     object
#  8   Estrato                 23 non-null     object
#  9   Precio                  23 non-null     float64
#  10  Tipo de Inmueble        23 non-null     object
#  11  Datos Adicionales       23 non-null     object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 2.3+ KB

# %% [markdown]
# >#### Ejecutamos el comando `df = df.drop_duplicates()` para eliminar registros duplicados en caso de que existan

# %%
df = df.drop_duplicates()

# %% [markdown]
# >#### Verificamos nuevamente el contenido de nuestros datos para saber si existian registros duplicados

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1333 entries, 0 to 1347
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   edad          1333 non-null   int64
#  1   sexo          1333 non-null   object
#  2   imc           1333 non-null   float64
#  3   hijos         1333 non-null   int64
#  4   fumador       1333 non-null   object
#  5   region        1333 non-null   object
#  6   valor_seguro  1333 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 83.3+ KB

# %% [markdown]
# >#### Podemos ordenar los datos de acuerdo con la edad, puesto que es una de las variables de estudio
# >#### El comando `df.sort_values('edad')` nos permite ordenar los datos por edad de menor a mayor
# >#### El comando `edad = df.sort_values('edad',ascending=False)` nos permite ordenar los datos por edad de mayor a menor

# %%
edad = df.sort_values('edad')

# %%
edad
# Out:
#       edad sexo    imc  hijos fumador        region  valor_seguro
# 1097    18    F  31.35      4      no        Boyaca    4561.18850
# 59      18    M  31.68      2     yes  Cundinamarca   34303.16720
# 1251    18    M  33.33      0      no  Cundinamarca    1135.94070
# 297     18    M  22.99      0      no        Boyaca    1704.56810
# 1255    18    F  39.82      0      no  Cundinamarca    1633.96180
# ...    ...  ...    ...    ...     ...           ...           ...
# 536     64    M  40.48      0      no  Cundinamarca   13831.11520
# 64      64    M  24.70      1      no     Antioquia   30166.61817
# 1248    64    M  36.96      2     yes  Cundinamarca   49577.66240
# 422     64    M  33.88      0     yes  Cundinamarca   46889.26120
# 637     64    M  38.19      0      no        Boyaca   14410.93210
#
# [1333 rows x 7 columns]

# %%
edad = df.sort_values('edad',ascending=False)

# %%
edad
# Out:
#       edad sexo     imc  hijos fumador        region  valor_seguro
# 422     64    M  33.880      0     yes  Cundinamarca   46889.26120
# 754     64    M  37.905      0      no     Antioquia   14210.53595
# 404     64    F  32.965      0      no     Antioquia   14692.66935
# 420     64    M  39.160      1      no  Cundinamarca   14418.28040
# 380     64    F  30.115      3      no     Antioquia   16455.70785
# ...    ...  ...     ...    ...     ...           ...           ...
# 1290    18    M  30.030      1      no  Cundinamarca    1720.35370
# 1289    18    F  21.660      0     yes        Boyaca   14283.45940
# 566     18    F  32.120      2      no  Cundinamarca    2801.25880
# 1082    18    M  21.780      2      no  Cundinamarca   11884.04858
# 1303    18    M  26.125      0      no        Boyaca    1708.92575
#
# [1333 rows x 7 columns]

# %% [markdown]
# >#### Agrupar los datos es una parte importante para el proceso de manipulacion de datos debido a que permite una mayor claridad en el analisis.
# >#### En este caso utilizaremos el rango de edad ya que es una de las variables objeto de analisis, por lo tanto procedemos a definir los rangos de edades

# %%
rangos = [17,28,38,48,58,68]

# %% [markdown]
# >#### Establecemos el nombre para cada rango

# %%
nombreRango = ['A','B','C','D','E']

# %% [markdown]
# >#### Creamos una nueva columna llamada _**Rango_Edad**_ donde agruparemos los datos segun el rango de edad previamente definido

# %%
df['Rango_Edad'] = pd.cut(df['edad'], rangos, labels=nombreRango)

# %% [markdown]
# >#### Los datos quedaran agrupados de la siguiente forma:
# >![Captura de Pantalla 2023-12-04 a la(s) 4.08.21 p. m..png](attachment:fdf01490-0337-4ba1-9300-f4d434a0ca26.png)

# %% [markdown]
# >#### Con el comando `df.describe()` podemos analizar las medidas de tendencia central que permitirán revisar el comportamiento de los datos desde el punto de vista del análisis estadístico

# %%
df.describe()
# Out:
#               edad          imc        hijos  valor_seguro
# count  1333.000000  1333.000000  1333.000000   1333.000000
# mean     39.195049    30.652097     1.092273  13261.908454
# std      14.052008     6.097609     1.205484  12093.507648
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.220000     0.000000   4738.268200
# 50%      39.000000    30.360000     1.000000   9377.904700
# 75%      51.000000    34.675000     2.000000  16657.717450
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# >#### Otra medida que se puede aplicar para el análisis de datos es el uso de diferentes tipos de _gráficos_, los cuales permiten una visualización más clara. Con el uso de los gráficos, se puede realizar una distribución mucho más _efectiva de los datos, lo que _facilita su interpretación_

# %% [markdown]
# >#### Para determinar el total de valores porcentualmente pagados al seguro por personas no fumadoras y fumadoras, se usa el siguiente comando, el cual genera un gráfico de total porcentual.

# %%
fig, ax = plt.subplots()
fumador = ['no', 'yes']
cantidad = df['fumador'].groupby(df['fumador']).count()
bar_labels = ['NO', 'YES']
bar_colors = ['tab:red', 'tab:green']
ax.bar(fumador, cantidad, label=bar_labels, color=bar_colors)
ax.set_ylabel('# de Personas')
ax.set_title('Cantidad de Fumadores')
plt.show()

# %%
total_fumador = df['fumador'].groupby(df['fumador']).count()
labels = ['NO', 'YES']
plt.pie(total_fumador, labels=labels, autopct='%.1f%%')
plt.show()

# %%
total_rango_edad = df['Rango_Edad'].groupby(df['Rango_Edad'], observed=True).count()
labels = ['A', 'B', 'C', 'D', 'E']
plt.pie(total_rango_edad, labels=labels, autopct='%.1f%%')
plt.show()

# %%
df.hist(bins=20,figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'edad'}>,
#         <Axes: title={'center': 'imc'}>],
#        [<Axes: title={'center': 'hijos'}>,
#         <Axes: title={'center': 'valor_seguro'}>]], dtype=object)

# %%
sns.histplot(df.imc,color="r",bins=30,kde=True)
plt.show()

# %%
plt.Figure(figsize=(10,7))
sns.countplot(df.Rango_Edad)
plt.show()

# %%
total_hijos = df['hijos'].groupby(df['hijos']).count()
etiquetas = [0,1,2,3,4,5]
colors = sns.color_palette('pastel')[0:6]
plt.pie(total_hijos, labels = etiquetas, colors = colors,
autopct='%.0f%%')
plt.show()

# %%
total_rango_edad = df['Rango_Edad'].groupby(df['Rango_Edad'], observed=True).count()
labels = ["A", "B", "C", "D", "E"]
colors = sns.color_palette('Set2')[0:5]
plt.pie(total_rango_edad, labels = labels, colors =
colors, autopct='%.1f%%')
plt.show()

# %%
Redad_valor = sns.boxplot(x=df["Rango_Edad"], y=df["valor_seguro"])

# %%
fumador_valor = sns.boxplot(x=df["fumador"], y=df["valor_seguro"])

# %% [markdown]
# >#### Para establecer la correlación entre las variables que permiten identificar una cercanía, se precisa el siguiente comando

# %%
correlacion = df.corr(numeric_only=True)

# %%
sns.heatmap(correlacion, xticklabels=correlacion.columns, yticklabels=correlacion.columns, annot=True)
# Out:
# <Axes: >

# %%
sns.relplot(x='Rango_Edad',
            y='valor_seguro', hue='fumador', data=df)

# %%
sns.barplot(data=df, x='region', y='valor_seguro', hue='fumador')
# Out:
# <Axes: xlabel='region', ylabel='valor_seguro'>
